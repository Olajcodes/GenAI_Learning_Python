# %%
# Document A: FAQ
strategy_A = "Fixed_Size Chunking (Character-Based)"
reason_A = "FAQ deals with a very precise answers to specific questions hence, less noise is required of it's content  and it needs a small chunks."    
# chunks_A =

FAQ = """
Q: What is the return policy?
A: Items can be returned within 30 days of purchase with original receipt.

Q: Do you offer international shipping?
A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.

Q: How do I track my order?
A: Use the tracking number sent to your email after shipment.
"""

def faq_chunking(text, chunk_size=600, overlap=50):
    """
    Split text into chunks of specified character length.
    
    Args:
        text: The text to chunk
        chunk_size: Number of characters per chunk
        overlap: Number of characters to overlap between chunks
    
    Returns:
        List of text chunks
    """
    chunks = []
    start = 0
    
    while start < len(text):
        # Get chunk from start to start + chunk_size
        end = start + chunk_size
        chunk = text[start:end]
        chunks.append(chunk)
        
        # Move start position (with overlap)
        start += chunk_size - overlap
    
    return chunks

# Test it
chunks = faq_chunking(FAQ, chunk_size=370, overlap=50)

print(f"Number of chunks: {len(chunks)}\n")
for i, chunk in enumerate(chunks[:3], 1):  # Show first 3 chunks
    print(f"Chunk {i} ({len(chunk)} chars):")
    print(chunk)
    print("-" * 80)
# Out:
# Number of chunks: 1
#
# Chunk 1 (319 chars):
#
# Q: What is the return policy?
# A: Items can be returned within 30 days of purchase with original receipt.
#
# Q: Do you offer international shipping?
# A: Yes, we ship to over 50 countries worldwide. Shipping times vary by location.
#
# Q: How do I track my order?
# A: Use the tracking number sent to your email after shipment.
#
# --------------------------------------------------------------------------------

# %%
# Technical Documents

Technical_doc = """
Installation Guide

Step 1: Download the installer from our website.
Extract the zip file to your desired location.

Step 2: Run setup.exe as administrator.
Follow the on-screen instructions.

Step 3: Configure your API key in the settings file.
The settings file is located at config/settings.json.
"""

def technical_chunk(text, min_chunk_size=100):
    """
    Split text by paragraphs (double newlines).
    
    Args:
        text: The text to chunk
        min_chunk_size: Minimum characters per chunk (combine small paragraphs)
    
    Returns:
        List of text chunks
    """
    # Split by double newlines (paragraph separator)
    paragraphs = text.split('\n\n')
    
    chunks = []
    current_chunk = ""
    
    for para in paragraphs:
        para = para.strip()
        if not para:
            continue
            
        # If paragraph is too small, combine with next
        if len(para) < min_chunk_size:
            current_chunk += "\n\n" + para if current_chunk else para
        else:
            # Save previous chunk if exists
            if current_chunk:
                chunks.append(current_chunk.strip())
            # Start new chunk with this paragraph
            current_chunk = para
    
    # Don't forget the last chunk
    if current_chunk:
        chunks.append(current_chunk.strip())
    
    return chunks

# Test it
chunks = technical_chunk(Technical_doc, min_chunk_size=100)

print(f"Number of chunks: {len(chunks)}\n")
for i, chunk in enumerate(chunks, 1):
    print(f"Chunk {i} ({len(chunk)} chars):")
    print(chunk)
    print("-" * 80)
